# %% [markdown]
# # **🧬 생물정보학과 파이썬 💻**

# %% [markdown]
# * <img src="https://microbenotes.com/wp-content/uploads/2018/12/Bioinformatics-Introduction-and-Applications.jpg">

# %% [markdown]
# # **Chapter 2:** **제어 구조**
#
#
# # 🧬 제어 구조를 알아보자~!!
#
# - 이 장에서는 **파이썬 프로그램이 생물학적 데이터 분석에 필수적인 기술인 결정을 내리고 행동을 반복하도록 하는 방법**을 배웁니다!
#
#
#
# ## 🎯 실습 목표
#
# 이 장이 끝나면 여러분은 다음을 수행할 수 있습니다.
#
# - 🔁 조건문(if/else)을 사용하여 생물학적 데이터를 분석할 수 있습니다.
# - 🧮 실제 생물학적 문제에 적용할 수 있습니다.
#
#
#
# ## 🔬 생명과학에서 제어 구조가 중요한 이유
#
# - 🧫 특성에 따라 유기체를 분류할 수 있습니다.
# - 🧍 여러 실험 샘플을 분석할 수 있습니다.
# - 💻 대규모 데이터 세트를 효율적으로 처리할 수 있습니다.
# - 🔬 재사용 가능한 분석 도구를 만들 수 있습니다.
# - 🧮 반복적인 실험실 계산을 자동화할 수 있습니다.

# %% [markdown]
# ```python

# %% [markdown]
# ## 🧩 조건문 - 의사 결정
#
#
# 조건문을 사용하면 프로그램이 **데이터를 기반으로 결정을 내릴 수 있습니다.**
# 조건문은 **생물학적 분류 및 데이터 분석**에 매우 적합합니다!
#
#
#
# ### 🧬 생물학적 응용
#
# - 🧫 특성별로 유기체를 분류합니다.
# - 🧪 실험 결과가 유의한지 확인합니다.
# - 📊 측정값이 정상 범위 내에 속하는지 확인합니다.
# - 🧬 서열의 돌연변이를 식별합니다.

# %% [markdown]
# ```python

# %% [markdown]
# ## 🧠 파이썬 제어 흐름: `if`, `elif`, `else`
#
# 파이썬에서 `if`, `elif`, `else`는 **조건문(Conditional Statements)** 으로,
# 주어진 **조건에 따라 프로그램의 흐름을 제어**할 때 사용됩니다.
#
#
#
# ### ✅ 각 키워드의 의미
#
# | 키워드 | 설명 |
# |---------|------|
# | `if`    | **조건이 참(`True`)일 때** 해당 코드 블록을 실행합니다. |
# | `elif`  | **이전 조건이 거짓(`False`)이고**, 새로운 조건이 **참(`True`)일 때** 실행됩니다. |
# | `else`  | **위의 모든 조건이 거짓(`False`)일 때** 실행됩니다. |

# %% [markdown]
# ```python

# %% [markdown]
# ## 🧩 기본 `if` 문 (BASIC IF STATEMENTS)
#
# `if` 문은 **주어진 조건이 참(`True`)일 때만 특정 코드 블록을 실행**하도록 하는 제어 구조입니다.
# 이 문법은 생물학적 데이터 분석에서 **특정 조건에 따라 데이터 처리 방법을 달리할 때** 매우 유용합니다.
#
#
#
# ### ✅ 기본 구조
#
# ```python
# if 조건:
#     실행할 코드

# %%
# 세균 생장 온도 판정
temperature = 34

if temperature >= 35:
  print("세균이 성장하기에 적합한 온도이다")

# %%
if temperature < 35:
  print("성장하기 어렵다")

# %%
# pH 판정
ph_level = 7.0

if ph_level == 7.0:
    print("중성 pH")
if ph_level > 7.0:
    print("염기성 pH")
if ph_level < 7.0:
    print("산성 pH")

# %%
# 연구를 위한 세균 생존율
cell_survival = 0.85

if cell_survival >= 0.8:
    print("✅ 실험에 적합한 생존율을 보인다")

# %% [markdown]
# ```python

# %% [markdown]
# ## 🧩 `if-else` 문 (IF-ELSE STATEMENTS)
#
# `if-else` 문은 **조건이 참(`True`)일 때 한 코드 블록을**,
# **거짓(`False`)일 때는 다른 코드 블록을 실행하도록** 하는 제어 구조
# 이 문법은 **두 가지 이상의 결과 중 하나를 선택해야 하는 생물학적 분석 상황**에서 자주 사용됨
#
#
#
# ### ✅ 기본 구조
#
# ```python
# if 조건:
#     실행할 코드 (조건이 참일 때)
# else:
#     실행할 코드 (조건이 거짓일 때)

# %%
# 세균 배양 온도에 따른 생장 상태 판정
temperature = 34  # 섭씨 온도

if temperature > 40:
    print("세균 성장이 억제됩니다.")
else:
    print("세균이 정상적으로 성장할 수 있습니다.")

# %%
# DNA 샘플 간 염기서열 비교를 통한 변이 검출
control_sequence = "ATCGATCG"   # 대조군(정상) DNA 서열
experiment_sequence = "ATGGATCG"  # 실험군 DNA 서열

if control_sequence == experiment_sequence:
    print("변이가 발견되지 않았습니다.")
else:
    print("염기 서열에 변이가 있습니다!.")

# %%
# 항균 물질 처리 전후의 세균 수 비교
bacteria_count_before = 1200   # 항균 물질 처리 전 세균 수 (CFU)
bacteria_count_after = 300     # 항균 물질 처리 후 세균 수 (CFU)

if bacteria_count_after < bacteria_count_before:
    print("항균 물질이 효과적으로 세균을 억제했습니다.")
else:
    print("항균 효과가 나타나지 않았습니다.")

# %% [markdown]
# ```python

# %% [markdown]
# ## 🧩 `elif` 문 (ELIF STATEMENTS: 다중 조건문)
#
# `elif` 문은 **여러 조건을 순차적으로 검사**하여
# 참(`True`)인 조건을 만족하는 **하나의 코드 블록만 실행**하도록 하는 제어 구조입니다.
# 이 문법은 **생물학적 데이터나 실험 결과를 여러 범주로 분류해야 할 때** 자주 사용됩니다.
#
#
#
# ### ✅ 기본 구조
#
# ```python
# if 조건1:
#     실행할 코드 (조건1이 참일 때)
# elif 조건2:
#     실행할 코드 (조건2가 참일 때)
# else:
#     실행할 코드 (모든 조건이 거짓일 때)

# %%
# DNA 농도에 따른 시료 품질 판정
dna_concentration = 15  # DNA 농도 (ng/μL)

if dna_concentration < 30:
    print("DNA 농도가 너무 낮아 실험에 사용할 수 없습니다.")
elif dna_concentration < 70:
    print("DNA 농도가 다소 낮지만, 일부 실험에서는 사용 가능합니다.")
elif dna_concentration < 120:
    print("DNA 농도가 적절하여 대부분의 분자생물학 실험에 적합합니다.")
else:
    print("DNA 농도가 너무 높아 희석 후 사용하는 것이 좋습니다.")

# %%
# DNA 순도에 따른 시료 등급 분류
# 260/280 비율은 DNA 순도를 나타내며, 1.8~2.0 범위가 일반적으로 순수한 DNA를 의미함.

od = 2.0    # 260/280 비율  # OD = Optical Density, 흡광도

if od < 1.7:
    category = "불순물 혼입"
elif od < 1.9:
    category = "보통 수준의 DNA 순도"
elif od <= 2.1:
    category = "고순도 DNA 시료"
else:
    category = "흡광도 측정 오류 가능성 있음"

print(f"DNA 260/280 비율: {od:.2f} -> 판정: {category}")

# %% [markdown]
# ## 🧩 if 조건문의 중첩 (Nested if Statements)
#
# `if` 조건문 안에 또 다른 `if` 조건문을 포함시킬 수 있으며, 이를 **중첩 조건문(Nested if)** 이라고 합니다.
# 이 구조는 **두 가지 이상의 조건을 동시에 고려해야 하는 생물학적 실험이나 데이터 분석 상황**에서 자주 사용됩니다.
#
#
#
# ### ✅ 기본 구조
#
# ```python
# if 조건1:
#     if 조건2:
#         실행할 코드 (두 조건이 모두 참일 때)
#     else:
#         실행할 코드 (조건1은 참, 조건2는 거짓일 때)
# else:
#     실행할 코드 (조건1이 거짓일 때)

# %%
# if 조건문은 중첩해서 사용할 수 있음.
# in 연산은 변수안에 해당 요소가 있는지 판별시 사용
# input()를 활용해서 if문 중첩을 진행

seq = input("서열을 입력하세요: ")

if seq:
  if "T" in seq:
    print("입력한 서열은 DNA 이다")
  elif "U" in seq:
    print("입력한 서열은 RNA이다")
  else:
    print("입력한 데이터는 뉴클레오타이드가 아니다")
else:
  print("서열을 입력하지 않았습니다.")

# %%
seq = input("서열을 입력하세요")

if seq:
  if "T" in seq:
    print("DNA 서열입니다")
  elif "U" in seq:
    print("RNA 서열입니다")
  else:
    print("염기서열이 아닙니다")
else:
  print("서열을 입력하세요")

# %%
# 아래 코드에 1개 or 2개의 염기서열을 입력하면 어떻게 될까?

seq = input("서열을 입력하세요: ")
extra_seq_len = len(seq)
extra_seq = len(seq) % 3 # %는 나머지를 구하는 연산자

if seq:
  if extra_seq == 1:
    print("여분의 뉴클레오타이드가 1개 존재합니다.")
  elif extra_seq == 2:
    print("여분의 뉴클레오타이드가 2개 존재합니다.")
  else:
    print("여분의 뉴클레오타이드가 존재하지 않습니다")
else:
  print("서열을 입력하지 않았습니다.")

print(extra_seq_len)

# %%
# 1개나 2개의 염기서열을 입력한 경우 오류가 나기 때문에 조건문을 추가해야 한다.

seq = input("서열을 입력하세요: ")
extra_seq = len(seq) % 3

if seq:
  if len(seq) >= 3:    # 서열의 길이가 3 이상일 경우 True
    if extra_seq == 1:
      print("여분의 뉴클레오타이드가 1개 존재합니다.")
    elif extra_seq == 2:
      print("여분의 뉴클레오타이드가 2개 존재합니다.")
    else:
      print("여분의 뉴클레오타이드가 존재하지 않습니다")
  else:
    print("Error"); print("서열을 3개 이상 입력하세요")
else:
  print("서열을 입력하지 않았습니다.")

# %% [markdown]
# ```python

# %% [markdown]
# # ============================================================
# # 🧬 CHAPTER 2 정리: 제어 구조 (Control Structures)
# # ============================================================
#
# ✅ **배운 내용**
# - 조건문: `if`, `elif`, `else`
# - 중첩 조건문 (Nested if)
# - `%` 연산자를 활용한 코돈 판정
# - 입력값 검증과 오류 처리
# - 생물학 데이터 분류 자동화
#
# 🧬 **생명과학 응용**
# - DNA/RNA 서열 판별 (`T`, `U` 포함 여부)
# - DNA 농도 및 순도(260/280 비율) 판정
# - 항균 물질 처리 효과 비교
# - 염기서열 길이에 따른 코돈 분류
