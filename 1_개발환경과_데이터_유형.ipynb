# %% [markdown]
# # **🧬 생물정보학과 파이썬 💻**

# %% [markdown]
# * <img src="https://microbenotes.com/wp-content/uploads/2018/12/Bioinformatics-Introduction-and-Applications.jpg">

# %% [markdown]
# # **🎯파이썬 개발 환경**
#
# * 개발환경은 파이썬 코드를 **작성, 실행, 디버깅, 그리고 관리**할 수 있도록 도와주는 다양한 도구와 소프트웨어들을 총칭
#
# * Colab은 구글에서 만든 **통합 개발 환경**이며 설치가 필요없음

# %% [markdown]
# #**🔬 GOOGLE COLAB이란 무엇인가?**
#
#
# - Google Colab은 브라우저에서 Python 코드를 작성하고 실행할 수 있는 무료 온라인 플랫폼
#
# - 데이터 분석
# - 그래프 및 시각화 작성
# - 연구 코드 공유
# - 동료와의 협업
#
# #**🧬 생물학을 위해 PYTHON을 사용해야 하는 이유**
#
# - DNA 서열 분석
# - 실험 데이터 처리
# - 고품질 그래프 만들기
# - 반복 계산 자동화
# - 재현 가능한 연구 공유그래프 및 시각화 작성
# - 연구 코드 공유
# - 동료와의 협업

# %% [markdown]
# ## **💻 코랩 기본 설정과 단축키**
#
# - 코랩 우측 상단의 **"연결"** 버튼을 클릭하여 서버와 코랩을 연동
#
# - **코랩 기본 단축키**
#
# |단축키|설명|
# |------|---|
# |**Ctrl + M + B**|아래에 코드셀 생성 |
# |**Ctrl + M + D**|선택된 코드셀 삭제 |
# |**Ctrl + Enter**|선택된 셀의 코드를 실행|
# |**Shift + Enter**|선택된 셀을 실행하고 다음셀로 이동|
# |**Alt + Enter**|선택된 셀을 실행하고 아래에 코드셀 생성|
#
#
# * 아래의 코드셀에 **"생물정보학을 위한 파이썬"**을 입력하고
# 단축키를 한번씩 실행해 보세요

# %% [markdown]
# # =============================================================
# # 파이썬의 출력
# # ==============================================================

# %%
'생물정보학과 바이오파이썬'
# Out:
# '생물정보학과 바이오파이썬'

# %% [markdown]
# # **주석** - 코드 문서화
#
# - 주석은 파이썬이 코드로 인식하지 않는 텍스트이며 사람이 읽을 수 있다.
# - **사용법**
# | 구분 | 설명 |
# |:--|:--|
# | 🧩 **분석의 기능 설명** | 코드의 구조와 동작 방식을 체계적으로 파악하여 개발자가 코드를 더 깊이 이해하고 개선할 수 있도록 돕는 기능 |
# | 🤝 **공동 작업자가 코드를 이해하도록 지원** | 협업 환경에서 팀원들이 코드의 목적, 흐름, 변경 이유를 쉽게 파악하도록 주석·문서화·시각적 분석 등을 통해 이해를 지원 |

# %%
print("생물정보학과 바이오파이썬")  # 출력시에는 print()를 사용함
# Out:
# 생물정보학과 바이오파이썬

# %% [markdown]
# # **변수** - 데이터 저장
#
# ### 변수는 데이터 값을 저장하기 위한 컨테이너이다. 실험실에 있는 라벨이 붙은 시험관이라고 생각하기!
#
# 🧪 변수에 대한 명명 규칙:
#
# * 문자 또는 밑줄로 시작해야 한다.
# * 문자, 숫자 및 밑줄을 포함할 수 있다.
# * 대소문자 구분(DNA ≠ dna)
# * 설명이 포함된 이름 사용

# %%
# 잘못된 변수의 예시
x = "BRCA1"        # 의미가 불명확함 (설명력이 부족함)
2gene = "BRCA1"      # 숫자로 시작함 (오류!)
gene-name = "BRCA1"  # 하이픈(-)이 포함됨 (오류!)
# Out:
#   File "/tmp/ipython-input-3653633094.py", line 3
#     2gene = "BRCA1"      # 숫자로 시작함 (오류!)
#     ^
# SyntaxError: invalid decimal literal

# %%
# 생물정보학에서 사용되는 다양한 변수의 예시
organism = "E.coli"      # 대장균
growth_temperature = 37  # 배양 온도
plasmid_length = 4361    # 원형의 플라스미드 길이

# %%
# 변수 출력
print(organism)
print(growth_temperature)
print(plasmid_length)
# Out:
# E.coli
# 37
# 4361

# %%
# 변수에 설명을 덧붙여 출력
print("유기체: ", organism)
print("성장 온도: ", growth_temperature, "℃")   # 한글 모드에서 F + 한자 입력시 ℃ 선택가능
print("플라스미드 길이: ",plasmid_length ,"bp")  # bp = base pair,  염기쌍
# Out:
# 유기체:  E.coli
# 성장 온도:  37 ℃
# 플라스미드 길이:  4361 bp

# %% [markdown]
# ## **파이썬의 데이터 유형**
#
# |유형|표기|설명|예시|
# |------|---|---|---|
# |**integer**|int|소수점이 없는 정수 |1, 2, 3, 4 |
# |**float**|float|소수점을 포함하는 실수 |1.5, 3.6, 12.78 |
# |**string**|str|" "or' '사용, 문자, 숫자, 기호가 포함된 글자|"DNA", 'RNA', "유전자"|
# |**list**|list|[ ]사용, 쉼표로 구분된 여러 개의 데이터|["DNA", "RNA", "단백질"]|
# |**tuple**|tuple|( )사용, list와 유사하지만 수정 불가|("DNA", "RNA", "단백질")|
# |**dictionary**|dict|{ }사용, key와 value로 묶인 항목|{'key' : 'value'}, {'A' : '아데닌'}, {'G' : '구아닌'}|

# %% [markdown]
# ---

# %%
# 정수(integers) – 개수, 나이, 세대수 등에 사용
chromosome_count = 46      # 염색체 수
individual_count = 120     # 개체 수
generation_number = 5      # 세대수

# %%
print("염색체수: ", chromosome_count)
print("개체수: ", individual_count)
print("세대수: ", generation_number)

# %% [markdown]
#   ---

# %%
# 실수(FLOATS, 소수형) – 측정값, 농도 등에 사용
growth_temperature = 37.0        # 성장 온도
ph_level = 7.4                   # pH 수치
protein_concentration = 15.8     # 단백질 농도

# %%
print("성장 온도:", growth_temperature,"℃")
print("pH 수치: ", ph_level)
print("단백질 농도: ", protein_concentration, "㎎/㎖")  # (한글모드) ㄹ + 한자에서 단위 선택

# %% [markdown]
# ---

# %%
# 문자열(string) – 이름, 서열, 설명 등에 사용
species = "Homo sapiens"         # 종 이름
dna_sequence = "ATCGTAGCTA"      # DNA 염기서열
notes = "구강에서 채취한 샘플"   # 실험 노트: 구강에서 채취한 샘플

# %%
print("Species: ", species)
print("유전자 서열: ",dna_sequence)
print("설명: ", notes)

# %% [markdown]
# ---

# %%
#✨ f-string은 formatted(형식화된) 의 약자로 문자열 앞에 f를 붙이고 중괄호 {} 안에 변수를 넣으면 자동으로 값이 출력됨.

# %%
organism = "E.coli"
growth_temperature = 37
genome_length = 4641652

print(f"{organism}은 {growth_temperature}℃에서 성장하고, 유전체의 길이는 {genome_length:,}이다")  # :, 숫자 자리수 구분

# %%
humidity = 65.2          # 습도
survival_rate = 0.9643   # 생존율

print(f"{organism}은 습도 {humidity}%에서 생존율이 {survival_rate:.2f}%이다")  # :.2f는 float를 둘째자리까지 표시하란 의미

# %% [markdown]
# ============================================================
# # INTERACTIVE EXERCISES
# ============================================================
#
# **Mission Ⅰ**
# - 나만의 연구 계획서 만들기
# - 자신의 연구 계획 정보가 담긴 변수를 만들고 출력하기

# %%
# 자신이 하고 싶은 연구 계획에 대해 입력하기
title = "식물의 광합성 효율 향상을 위한 유전자 탐색"
target = "애기장대"
method ="광합성 관련 DNA 추출"
duration = "1년"

print(f"연구 주제:{title}")
print(f"연구 대상:{target}")
print(f"연구 방법:{method}")
print(f"연기 기간:{duration}")

# %% [markdown]
# # ============================================================
# # 🧠 CHAPTER 1 정리: 개발환경과 데이터 유형
# # ============================================================
#
# ✅ **배운 내용**
# - Google Colab 환경 설정 및 단축키
# - Python 기초 문법 (`print`, 변수, 주석)
# - 자료형: string, integer, float
#
#
# 🧬 **생명과학 응용**
# - 연구 계획 데이터 입력 및 출력

# %% [markdown]
# **Mission Ⅱ**
# - DNA 서열 계산하기
# - len()는 데이터 내부의 요소의 개수를 세는 함수
# - count()는 특정 요소가 데이터 안에 몇 번 등장하는지를 세는 함수

# %%
# DNA 염기서열
dna_seq = "ATGCGATCGTAGCTAGCATGC"

# DNA 서열 길이 계산
dna_length = len(dna_seq)

# %%
print(f"{dna_seq}의 길이는 {dna_length}bp이다.")
# Out:
# ATGCGATCGTAGCTAGCATGC의 길이는 21bp이다.

# %%
# 특정 염기의 개수 세기
# count_A = dna_seq.count("A")
# count_T = dna_seq.count("T")
# count_G = dna_seq.count("G")
# count_C = dna_seq.count("C")

# %%
print(f"A:{count_A}, T:{count_T}, G:{count_G}, C:{count_C}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-421230594.py in <cell line: 0>()
# ----> 1 print(f"A:{count_A}, T:{count_T}, G:{count_G}, C:{count_C}")
#
# NameError: name 'count_A' is not defined

# %%
# GC 함량 계산하기
GC_contents = ((count_G + count_C) / dna_length) * 100   # 100을 직접 곱하여 백분율 계산
print(f"GC 함량: {GC_contents:.2f}%")


GC_contents = ((count_G + count_C) / dna_length)         # 100을 곱하지 않음
print(f"GC 함량: {GC_contents:.2%}")                     # :.2%는 결과치를 백분율로 나타냄
